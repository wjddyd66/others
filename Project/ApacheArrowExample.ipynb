# %%
import numpy as np
import pandas as pd
import pyarrow as pa

# %% [markdown]
# Conveorting Pandas Dataframe to Apache Arrow Table

# %%
df = pd.DataFrame({'one': [20, np.nan, 2.5],'two': ['january', 'february', 'march'],'three': [True, False, True]},index=list('abc'))
table = pa.Table.from_pandas(df)
# Out:
# C:\Users\Administrator\Anaconda3\envs\work1\lib\site-packages\pyarrow\pandas_compat.py:114: FutureWarning: A future version of pandas will default to `skipna=True`. To silence this warning, pass `skipna=True|False` explicitly.
#   result = infer_dtype(pandas_collection)

# %% [markdown]
# Pyarrow Table to Pandas Data Frame

# %%
df_new = table.to_pandas()
# Out:
# C:\Users\Administrator\Anaconda3\envs\work1\lib\site-packages\pyarrow\pandas_compat.py:708: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# C:\Users\Administrator\Anaconda3\envs\work1\lib\site-packages\pyarrow\pandas_compat.py:735: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# C:\Users\Administrator\Anaconda3\envs\work1\lib\site-packages\pyarrow\pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels

# %% [markdown]
# Read CSV

# %%
from pyarrow import csv
fn = 'data.csv'
table = csv.read_csv(fn)
df = table.to_pandas()

# %% [markdown]
# Writing a parquet file from Apache Arrow

# %%
import pyarrow.parquet as pq
pq.write_table(table, 'example.parquet')

# %% [markdown]
# Reading a parquet file

# %%
table2 = pq.read_table('example.parquet')
table2
# Out:
# pyarrow.Table
# no: int64
# tv: double
# radio: double
# newspaper: double
# sales: double

# %% [markdown]
# Reading some columns from a parquet file

# %%
table2 = pq.read_table('example.parquet', columns=['one', 'three'])

# %% [markdown]
# Transforming Parquet file into a Pandas DataFrame

# %%
pdf = pq.read_pandas('example.parquet', columns=['two']).to_pandas()
pdf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Avoiding pandas index

# %%
table = pa.Table.from_pandas(df, preserve_index=False)
pq.write_table(table, 'example_noindex.parquet')
t = pq.read_table('example_noindex.parquet')
t.to_pandas()
# Out:
#       no     tv  radio  newspaper  sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0    9.3        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# Check metadata

# %%
parquet_file = pq.ParquetFile('example.parquet')
parquet_file.metadata
# Out:
# <pyarrow._parquet.FileMetaData object at 0x0000000007D9ECC8>
#   created_by: parquet-cpp version 1.5.1-SNAPSHOT
#   num_columns: 5
#   num_rows: 200
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 550

# %% [markdown]
# See data schema

# %%
parquet_file.schema
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x0000000007E074C8>
# no: INT64
# tv: DOUBLE
# radio: DOUBLE
# newspaper: DOUBLE
# sales: DOUBLE

# %% [markdown]
# In memory

# %%
writer = pa.BufferOutputStream()
writer.write(b'hello, friends')
buf = writer.getvalue()
print(buf)
print(buf.size)
# Out:
# <pyarrow.lib.Buffer object at 0x0000000007E067F0>
# 14

# %%
reader = pa.BufferReader(buf)
reader.seek(0)
reader.read(14)
# Out:
# b'hello, friends'
